# %%
print("안녕")
# Out:
# 안녕

# %%
print("a""b")
# Out:
# ab

# %%
print('c'"d")
# Out:
# cd

# %%
"""엔터 목적"""
# Out:
# '엔터 목적'

# %%
print("이름: 홍길동\n나이: 20")
# Out:
# 이름: 홍길동
# 나이: 20

# %%
print("홍길동", end = "")
print("안녕")
# Out:
# 홍길동안녕

# %%
# 파이썬은 키워드가 없다

a = 10
b = 10

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
# r"": 윈도우 환경에서 \ 또는 / 경로로 정확히 인식시키기 위한 문법
r"C:\back_0900\python\memo"
