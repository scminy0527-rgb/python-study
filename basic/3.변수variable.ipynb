# %%
name = "홍길동"
print(name)
# Out:
# 홍길동

# %% [markdown]
# 변수
#    - 값을 저장하는 저장공간이며, 값을 재사용하기 위해서 사용한다.
#
# 변수의 생성
#    x      =      10
#    변수명        대입연산자      값
#
# 변수의 사용
#    x
#
#
# 변수 선언 시 주의사항
#    1. 초기화를 해준다.
#    2. 되도록 선언부에 한꺼번에 선언한다(영역 상단).
#
#    ex)
#       2 x = 10;
#       3 y = 20;
#       ...
#       1234 print(x);
#       ...
#
#       7896
#       ...
#       10586 print(y);
#
# 변수명 주의사항
#    문자로 시작해야 한다.
#    특수문자는 사용할 수 없다. 단, _는 허용한다.
#    소문자로 시작한다.
#    공백을 사용할 수 없다.
#    되도록 한글은 사용하지 않는다.
#    명사로 사용한다.
#    뜻이 있는 단어를 사용한다.
#
#    a, b, c, d, e, ... (X)
#    data, number, age, name, ... (O)
#
#    *파이썬은 스네이크 표기법, 파스칼 표기법
#    happyDay(카멜 표기법), happy_day(스네이크 표기법),
#    happy-day(케밥 표기법), HappyDay(파스칼 표기법)
#
# 변수를 사용하는 이유
#    1. 반복되는 값을 쉽게 관리할 수 있다.
#    2. 의미 없는 값을 하나의 정보로 만들기 위해서 사용한다(자료구조).

# %%
age = 20

# %%
20 + "d"
# 1. js 처럼 자동 형변환 불가
# 2. None
# 3. 오류 Type Error
# int + String 불가
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 20 + "d"
#       2 # 1. js 처럼 자동 형변환 불가
#       3 # 2. None
#       4 # 3. 오류 Type Error
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# 특수 문자는 사용 불가, 언더바 만 사용

# %%
nAge = 20
# 카멜 표기 불가

# %%
# 공백문자 변수 금지
# 한글 변수명 금지
이름 = "홍길동"
print(이름)
# Out:
# 홍길동
