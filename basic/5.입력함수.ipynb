# %%
st = input("이름을 입력하세요")
# Out:
# 이름을 입력하세요 dd

# %%
num1 = input("첫번째 정수를 입력하세요")
num2 = input("두번째 정수를 입력하세요")
# Out:
# 첫번째 정수를 입력하세요 10
# 두번째 정수를 입력하세요 20

# %%
result = int(num1) + int(num2)
print(result)
# Out:
# 30
